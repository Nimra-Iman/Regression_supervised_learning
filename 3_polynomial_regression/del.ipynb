# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("Position_Salaries.csv")
dataset=dataset.drop("Position", axis=1)
dataset.head()
# Out:
#    Level  Salary
# 0      1   45000
# 1      2   50000
# 2      3   60000
# 3      4   80000
# 4      5  110000

# %%
x=dataset[["Level"]]
y=dataset["Salary"]

# %%
sns.scatterplot(x=dataset["Level"],y=y, data=dataset)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=3)
pf.fit(x)
# Out:
# PolynomialFeatures(degree=3)

# %%
x=pf.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 5.71254135e-06,  2.51292039e-07,  1.76593180e+04, -6.49625220e+03,
#         9.58699786e-12,  1.76593180e+04, -6.49625220e+03, -6.49625220e+03,
#         3.01789389e+03, -2.80900941e+02,  0.00000000e+00,  1.76593180e+04,
#        -6.49625220e+03, -6.49625220e+03,  3.01789389e+03, -2.80900941e+02,
#         3.01789389e+03, -2.80900941e+02, -7.82627866e+00,  3.85802469e+00])

# %%
lr.intercept_
# Out:
# 16296.296290339145

# %%
lr.score(x_test, y_test)
# Out:
# 0.9958043368443784

# %%
prd=lr.predict(x)
prd
# Out:
# array([  45000.00000001,   51269.84126985,   60000.        ,
#          80000.        ,  110000.        ,  147433.86243386,
#         199999.99999999,  299999.99999999,  521455.02645502,
#        1000000.        ])

# %%
sns.scatterplot(x=dataset["Level"],y=y, data=dataset)
plt.plot(dataset["Level"], prd, color="r")
plt.show()
