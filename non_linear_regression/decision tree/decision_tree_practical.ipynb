# %%
from IPython.display import Image
Image('tree_in_regression.jpeg', width=300, height=300)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('Salary_Data.csv')
dataset.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
x=dataset.drop(columns=['Salary'], axis=1)
y=dataset['Salary']

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.3, random_state=42)

# %%
# although data is linearly separable, we will still use decioisn tree, just for practice
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(max_depth=5)
dtr.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
dtr.score(x_train, y_train)*100, dtr.score(x_test, y_test)*100
# Out:
# (99.68018641288286, 91.02359746591037)

# %%
#### from sklearn.tree import plot_tree
plot_tree(dtr)
plt.show()
