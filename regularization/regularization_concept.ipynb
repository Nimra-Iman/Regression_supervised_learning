# %%
when we have pot of data in our dataset and bht sary features to useless hoty hn jis ki vja s model
ko train hony m bhhhhhtttt time lgta h or us ko prdict hony m bhi bhht time lgta h
is s bachny k liye hm regularization ko use krty hn, is s model ki performance bhi achi hoti h
-----> regularization is mostly used in linear regression but it is also used in other algos as well as in deep learning

# %%
HOW REGULARIZATION INVOLVE IN MODAL PERFORMANCE?
IT DID IT IN 2 WAYS:
    1-- it involves in feature selection as well (lasso regularization involve in it), y "m" ki value
ko exactly equal to 0 kr deta h

 2-- it avoid overfitting, yani y=200x1 + 300x2 + 0.5x3 ek linear regression k result
m equation bni to yhan "m" ki value kafi ziada hn 200 and 300 as compared to 0.5, to regularization
is "m" ki value ko yani coefficient ki value ko km kr k overfitting ko avoid krti h or is "m" ki bri value
ko km kr k hmary model ko computationaly inexpensiva bnata h (ridge regression involve here)

# %%
there are 2 techniques for regularization:
    Ridge regularization
    Lasso regularization

# %%
Ridge regularization ALSO CALLED RIDGE regression.
    baaz oqat hmary data m kisi variable ki "m" ki value ziada ho jati h or jab model train hony lgta h to us feature ko
    bht importance de deta h jis s problem ati h, hm regularization k zrye us variable/feature ki "m" ki value ko km krty hn

-----> yaad rhy k ridge regularization "m" ki value ko exactly zero nhi krta bal k zero k close kr kr deta h

# %%
from IPython.display import Image
Image(filename='ridge regularization.png', height=300, width=300)

# %%
y loss function k ander penalty ko add krta h, jesy jesy alpha ki value increase hoti h vesy vesy
"m" ki value kam hoti jati h ||w||^2 is actually sum of square of "m" of all variables
yani jitny ki features hn un sab ki "m" ki value ka square kro or phir us sa squared values ko plus kr do.

"m" ki value k ziada hony s hmara model computationaly expensive hota h and bht der lgata h train and predict krny m

# %%
LASSO REGULARIZATION (L1 REGULARIZATION): it has same formula as of ridge but m ki values ka square nhi krta and 
other thing is that k y m ki value ko bilkul zero bhi kr deta h yani agar kuch is trah s ho k y=200x1 + 300x2 + 20x3 + c
to y 20x3 valy ki m ki value yani 20 ko exactly equal to zero kr de ga yai us feature ko hiu khtam kr de ga , it involves in 
feature selection yani.

# %%
from IPython.display import Image
Image(filename='laso.png', height=300, width=300)
